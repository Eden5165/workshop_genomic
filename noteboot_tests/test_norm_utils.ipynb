# %% [markdown]
# # Imports

# %%
import data_prep_utils
import norm_utils

# %% [markdown]
# # Test sum_gene_exp_to_num (1)

# %%
beat_rna = data_prep_utils.get_df("beat_rnaseq")
tcga_rna = data_prep_utils.get_df("tcga_rna")
beat_rna_t = data_prep_utils.transpose_df(beat_rna)
tcga_rna_t = data_prep_utils.transpose_df(tcga_rna)

# %%
beat_rna_t.head()
# Out:
#             TSPAN6       DPM1      SCYL3   C1orf112          FGR        CFH  \
# 12-00066  0.070215  23.311415  10.532266  11.129094   906.792960   4.739520
# 12-00150  1.709459  32.137834  17.778376  11.253940    49.004499   8.262386
# 12-00211  0.000000  25.117470  37.659392  12.541923   111.834945   2.118341
# 12-00258  0.000000  29.351673  15.647852   8.190423  1004.458236  30.403362
# 12-00294  0.000000  31.240770  39.189992  18.875313   267.852800   2.388038
#
#               FUCA2       GCLC       NFYA      STPG1  ...  RP11-218F10.3  \
# 12-00066  43.849332  44.340838  57.435955   4.177799  ...       0.491506
# 12-00150  84.589743  39.346054  32.052361  10.199774  ...       0.142455
# 12-00211  59.078171  67.349788  77.470749   7.767250  ...       1.513101
# 12-00258  30.020930  44.011575  51.692089   5.035358  ...       0.286824
# 12-00294  37.325360  56.429663  60.060789   6.379005  ...       1.962771
#
#           RP11-686O6.2  RP11-313P22.1  RP11-548H3.1  RP11-102N12.3  \
# ...

# %%
tcga_rna_t.head()
# Out:
#                    A1BG  A1CF  A2BP1     A2LD1        A2M     A2ML1  \
# TCGA.AB.2803  21.786275   0.0    0.0  3.772166  24.673141  0.108692
# TCGA.AB.2805   5.251160   0.0    0.0  3.007237   0.995091  0.207309
# TCGA.AB.2806  10.866631   0.0    0.0  2.951634   0.406560  0.332639
# TCGA.AB.2807  18.869409   0.0    0.0  2.491801  18.714176  0.054085
# TCGA.AB.2808   8.199836   0.0    0.0  2.934105  15.931201  0.342311
#
#                  A4GALT     A4GNT  AAA1       AAAS  ...     ZWILCH      ZWINT  \
# TCGA.AB.2803   0.597809  0.000000   0.0  27.173063  ...  21.150422  13.043071
# TCGA.AB.2805   0.041459  0.165849   0.0  33.003750  ...  34.532453  23.301644
# TCGA.AB.2806   1.034880  0.073922   0.0  29.272380  ...  42.643793  25.650289
# TCGA.AB.2807   6.328205  0.270434   0.0  37.969229  ...  35.305970  39.321409
# TCGA.AB.2808  11.345199  0.048899   0.0  27.629468  ...  55.243286  48.119281
#
#                   ZXDA       ZXDB        ZXDC    ZYG11A      ZYG11B  \
# ...

# %%
beat_rna_sum_1 = norm_utils.sum_gene_exp_to_num(beat_rna_t, 1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_23912/969136145.py in <module>
# ----> 1 beat_rna_sum_1 = norm_utils.sum_gene_exp_to_num(beat_rna_t, 1)
#
# AttributeError: module 'norm_utils' has no attribute 'sum_gene_exp_to_num'

# %%
for i in range(1, 5):
    print(beat_rna_sum_1.iloc[:, i].sum())
beat_rna_sum_1.head()
# Out:
# 1.0
# 1.0
# 0.9999999999999998
# 0.9999999999999998
#    SampleID    TSPAN6      DPM1     SCYL3  C1orf112       FGR       CFH  \
# 0  12-00066  0.000782  0.003928  0.002632  0.004891  0.013171  0.001509
# 1  12-00150  0.019045  0.005416  0.004442  0.004945  0.000712  0.002631
# 2  12-00211  0.000000  0.004233  0.009410  0.005511  0.001624  0.000674
# 3  12-00258  0.000000  0.004946  0.003910  0.003599  0.014590  0.009680
# 4  12-00294  0.000000  0.005265  0.009793  0.008295  0.003891  0.000760
#
#       FUCA2      GCLC      NFYA  ...  RP11-218F10.3  RP11-686O6.2  \
# 0  0.004782  0.004736  0.004720  ...       0.003404      0.001028
# 1  0.009225  0.004203  0.002634  ...       0.000987      0.004590
# 2  0.006443  0.007194  0.006366  ...       0.010479      0.002216
# 3  0.003274  0.004701  0.004248  ...       0.001986      0.006068
# 4  0.004071  0.006027  0.004936  ...       0.013594      0.001437
#
#    RP11-313P22.1  RP11-548H3.1  RP11-102N12.3  RP11-196O16.1  RP4-671G15.2  \
# ...

# %%
tcga_rna_sum_1 = norm_utils.sum_gene_exp_to_num(tcga_rna_t, 1)

# %%
for i in range(1, 5):
    print(tcga_rna_sum_1.iloc[:, i].sum())
tcga_rna_sum_1.head()
# Out:
# 1.0
# 1.0
# 1.0
# 1.0
#        SampleID      A1BG  A1CF  A2BP1     A2LD1       A2M     A2ML1  \
# 0  TCGA.AB.2803  0.012028   0.0    0.0  0.006236  0.017993  0.001416
# 1  TCGA.AB.2805  0.002899   0.0    0.0  0.004972  0.000726  0.002700
# 2  TCGA.AB.2806  0.005999   0.0    0.0  0.004880  0.000296  0.004333
# 3  TCGA.AB.2807  0.010418   0.0    0.0  0.004120  0.013647  0.000705
# 4  TCGA.AB.2808  0.004527   0.0    0.0  0.004851  0.011618  0.004459
#
#      A4GALT     A4GNT  AAA1  ...    ZWILCH     ZWINT      ZXDA      ZXDB  \
# 0  0.000889  0.000000   0.0  ...  0.003914  0.002194  0.002381  0.004551
# 1  0.000062  0.009349   0.0  ...  0.006391  0.003919  0.001022  0.004207
# 2  0.001540  0.004167   0.0  ...  0.007892  0.004315  0.005365  0.009144
# 3  0.009415  0.015245   0.0  ...  0.006534  0.006614  0.011331  0.009460
# 4  0.016879  0.002756   0.0  ...  0.010224  0.008094  0.003415  0.006016
#
#        ZXDC    ZYG11A    ZYG11B       ZYX     ZZEF1      ZZZ3
# ...

# %% [markdown]
# # Test sum_gene_exp_to_num (mill)

# %%
beat_rna_sum_mil = norm_utils.sum_gene_exp_to_num(beat_rna_t, 1000000)
tcga_rna_sum_mil = norm_utils.sum_gene_exp_to_num(tcga_rna_t, 1000000)

# %%
for i in range(1, 5):
    print(beat_rna_sum_mil.iloc[:, i].sum())
beat_rna_sum_mil.head()
# Out:
# 999999.9999999999
# 1000000.0
# 999999.9999999998
# 999999.9999999998
#    SampleID        TSPAN6         DPM1        SCYL3     C1orf112  \
# 0  12-00066    782.280658  3928.460512  2631.811003  4890.622319
# 1  12-00150  19045.431120  5415.896716  4442.475018  4945.485352
# 2  12-00211      0.000000  4232.818530  9410.359206  5511.482467
# 3  12-00258      0.000000  4946.370325  3910.097804  3599.238881
# 4  12-00294      0.000000  5264.722598  9792.826721  8294.658012
#
#             FGR          CFH        FUCA2         GCLC         NFYA  ...  \
# 0  13171.110842  1509.054705  4782.055886  4736.174239  4719.859026  ...
# 1    711.787276  2630.729376  9225.063571  4202.666812  2633.935959  ...
# 2   1624.395555   674.475999  6442.860166  7193.827260  6366.238987  ...
# 3  14589.692844  9680.377089  3273.978302  4701.004690  4247.850883  ...
# 4   3890.545105   760.347083  4070.574070  6027.416860  4935.557470  ...
#
# ...

# %%
for i in range(1, 5):
    print(tcga_rna_sum_mil.iloc[:, i].sum())
tcga_rna_sum_mil.head()
# Out:
# 1000000.0000000002
# 1000000.0000000001
# 999999.9999999998
# 1000000.0
#        SampleID          A1BG  A1CF  A2BP1        A2LD1           A2M  \
# 0  TCGA.AB.2803  12028.095113   0.0    0.0  6236.388040  17992.509528
# 1  TCGA.AB.2805   2899.139627   0.0    0.0  4971.757645    725.654498
# 2  TCGA.AB.2806   5999.413196   0.0    0.0  4879.830578    296.477830
# 3  TCGA.AB.2807  10417.707305   0.0    0.0  4119.605270  13647.025197
# 4  TCGA.AB.2808   4527.088898   0.0    0.0  4850.851485  11617.584099
#
#          A2ML1        A4GALT         A4GNT  AAA1  ...        ZWILCH  \
# 0  1415.860372    889.397454      0.000000   0.0  ...   3914.350218
# 1  2700.487684     61.681535   9349.170162   0.0  ...   6390.988936
# 2  4333.086034   1539.654893   4167.067712   0.0  ...   7892.170491
# 3   704.527567   9414.864794  15244.734930   0.0  ...   6534.145229
# 4  4459.077283  16878.959712   2756.497816   0.0  ...  10223.983505
#
# ...

# %% [markdown]
# # Test gene_exp_log_trans

# %%
# beat_rna_log_1 = norm_utils.gene_exp_log_trans(beat_rna, 1)
beat_rna_log_mill = norm_utils.gene_exp_log_trans(beat_rna)

# tcga_rna_log_1 = norm_utils.gene_exp_log_trans(tcga_rna_sum_1, 1)
tcga_rna_log_mill = norm_utils.gene_exp_log_trans(tcga_rna)

# %%
beat_rna_log_mill.describe()
# Out:
#            12-00066      12-00150      12-00211      12-00258      12-00294  \
# count  22843.000000  22843.000000  22843.000000  22843.000000  22843.000000
# mean       4.502278      4.550235      4.604138      4.511846      4.627829
# std        1.461482      1.474066      1.481136      1.471452      1.486197
# min        3.321928      3.321928      3.321928      3.321928      3.321928
# 25%        3.366807      3.378355      3.383651      3.362726      3.386532
# 50%        3.796695      3.863796      3.930304      3.795773      3.968950
# 75%        5.305991      5.411602      5.558311      5.337541      5.602919
# max       14.167628     13.095665     13.883685     14.617816     13.780309
#
#            12-00372      13-00028      13-00034      13-00098      13-00118  \
# count  22843.000000  22843.000000  22843.000000  22843.000000  22843.000000
# mean       4.634766      4.585707      4.483837      4.517692      4.620302
# ...

# %%
beat_rna.describe()
# Out:
#            12-00066      12-00150      12-00211      12-00258      12-00294  \
# count  22843.000000  22843.000000  22843.000000  22843.000000  22843.000000
# mean      43.777087     43.777087     43.777087     43.777087     43.777087
# std      239.036200    179.037496    199.633444    255.030349    188.159584
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.315968      0.398874      0.437118      0.286824      0.457980
# 50%        3.896938      4.558558      5.245415      3.888061      5.659323
# 75%       29.560559     32.565199     37.121401     30.435231     38.601161
# max    18392.670950   8743.627777  15104.913180  25132.075360  14059.753090
#
#            12-00372      13-00028      13-00034      13-00098      13-00118  \
# count  22843.000000  22843.000000  22843.000000  22843.000000  22843.000000
# mean      43.777087     43.777087     43.777087     43.777087     43.777087
# ...

# %%
tcga_rna_log_mill.describe()
# Out:
#        TCGA.AB.2803  TCGA.AB.2805  TCGA.AB.2806  TCGA.AB.2807  TCGA.AB.2808  \
# count  20281.000000  20281.000000  20281.000000  20281.000000  20281.000000
# mean       4.616133      4.686806      4.672909      4.704069      4.715985
# std        1.515398      1.579850      1.573982      1.544839      1.576896
# min        3.321928      3.321928      3.321928      3.321928      3.321928
# 25%        3.329747      3.327897      3.332554      3.352808      3.335970
# 50%        3.993106      4.015947      3.976354      4.148485      4.091010
# 75%        5.604074      5.759077      5.732523      5.698152      5.805259
# max       14.925199     13.862681     14.039958     14.018325     14.132621
#
#        TCGA.AB.2810  TCGA.AB.2811  TCGA.AB.2812  TCGA.AB.2813  TCGA.AB.2814  \
# count  20281.000000  20281.000000  20281.000000  20281.000000  20281.000000
# mean       4.609821      4.538498      4.695363      4.670153      4.716283
# ...

# %%
tcga_rna.describe()
# Out:
#        TCGA.AB.2803  TCGA.AB.2805  TCGA.AB.2806  TCGA.AB.2807  TCGA.AB.2808  \
# count  20281.000000  20281.000000  20281.000000  20281.000000  20281.000000
# mean      49.307233     49.307233     49.307233     49.307233     49.307233
# std      358.799961    209.351193    218.698925    206.815311    205.849947
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.054346      0.041459      0.073922      0.216349      0.097804
# 50%        5.923727      6.177840      5.739898      7.734474      7.041845
# 75%       38.640096     44.157024     43.169368     41.917593     45.918709
# max    31102.325930  14886.446200  16834.131269  16583.430457  17951.505705
#
#        TCGA.AB.2810  TCGA.AB.2811  TCGA.AB.2812  TCGA.AB.2813  TCGA.AB.2814  \
# count  20281.000000  20281.000000  20281.000000  20281.000000  20281.000000
# mean      49.307233     49.307233     49.307233     49.307233     49.307233
# ...

# %% [markdown]
# # Test ic50_log_trans

# %%
beat_drug_df = data_prep_utils.get_df("beat_drug")
beat_drug_df.head()
# Out:
#                       12-00066   12-00150  12-00211   12-00258   12-00294  \
# A-674563              0.302313   0.183573      10.0   2.250759   0.312102
# Afatinib (BIBW-2992)  0.270839   0.095105      10.0   1.042656   0.412103
# Alisertib (MLN8237)   2.292925  10.000000      10.0  10.000000   1.731348
# Axitinib (AG-013736)  0.137656  10.000000      10.0  10.000000   0.124162
# AZD1480               2.429158        NaN      10.0  10.000000  10.000000
#
#                        12-00372   13-00028   13-00034   13-00098  13-00118  \
# A-674563               1.112644   3.699257   1.522665   5.132768   1.83987
# Afatinib (BIBW-2992)   0.492191   1.126676   0.313330   4.442185   1.09213
# Alisertib (MLN8237)    6.149094  10.000000  10.000000  10.000000  10.00000
# Axitinib (AG-013736)  10.000000  10.000000  10.000000  10.000000  10.00000
# AZD1480               10.000000  10.000000  10.000000  10.000000  10.00000
#
# ...

# %%
beat_drug_log = norm_utils.ic50_log_trans(beat_drug_df)

# %%
beat_drug_log.describe()
# Out:
#         12-00066   12-00150   12-00211   12-00258   12-00294   12-00372  \
# count  79.000000  79.000000  79.000000  79.000000  79.000000  79.000000
# mean   -0.226548   0.543510   0.818007   0.710352  -0.077377   0.467910
# std     1.030967   0.754165   0.499345   0.534819   0.906244   0.737821
# min    -2.853872  -2.163739  -1.862741  -1.862741  -2.225237  -1.862741
# 25%    -0.898967   0.273789   1.000000   0.590368  -0.605360   0.023178
# 50%    -0.350197   1.000000   1.000000   1.000000  -0.046818   0.854859
# 75%     1.000000   1.000000   1.000000   1.000000   0.850957   1.000000
# max     1.000000   1.000000   1.000000   1.000000   1.000000   1.000000
#
#         13-00028   13-00034   13-00098   13-00118  ...   16-01102   16-01138  \
# count  79.000000  79.000000  79.000000  79.000000  ...  79.000000  79.000000
# mean    0.625848   0.554665   0.792854   0.796274  ...   0.796292   0.576881
# std     0.564817   0.746492   0.517604   0.397184  ...   0.475184   0.658229
# ...
