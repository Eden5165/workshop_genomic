# %% [markdown]
# # Imports

# %%
import sys
import os
sys.path.append(os.path.dirname(os.getcwd()))

from utils import data_prep_utils
import pandas

# %%
os.path.join(os.path.dirname(os.getcwd()), "medical_genomics_2021_data", "u")
# Out:
# 'c:\\Users\\yaelz\\OneDrive - mail.tau.ac.il\\school_dev\\workShop\\workshop_genomic\\medical_genomics_2021_data\\u'

# %% [markdown]
# # Test get_df

# %%
dfs = {}

for table_name in os.listdir(os.path.join(os.path.dirname(os.getcwd()), "medical_genomics_2021_data")):
    dfs[table_name] = data_prep_utils.get_df(table_name, nb=True)

print(dfs.keys())
# Out:
# dict_keys(['beat_drug', 'beat_rnaseq', 'drug_mut_cor', 'drug_mut_cor_labels', 'folds.txt', 'tcga_mut', 'tcga_rna'])

# %%
dfs["beat_drug"].head()
# Out:
#            A-674563  Afatinib (BIBW-2992)  Alisertib (MLN8237)  \
# 12-00066   0.302313              0.270839             2.292925
# 12-00150   0.183573              0.095105            10.000000
# 12-00211  10.000000             10.000000            10.000000
# 12-00258   2.250759              1.042656            10.000000
# 12-00294   0.312102              0.412103             1.731348
#
#           Axitinib (AG-013736)    AZD1480  Barasertib (AZD1152-HQPA)  \
# 12-00066              0.137656   2.429158                       10.0
# 12-00150             10.000000        NaN                       10.0
# 12-00211             10.000000  10.000000                       10.0
# 12-00258             10.000000  10.000000                       10.0
# 12-00294              0.124162  10.000000                       10.0
#
#              BEZ235  BMS-345541  Bortezomib (Velcade)  Bosutinib (SKI-606)  \
# 12-00066   0.038276    1.246408              0.180191             0.325536
# ...

# %%
dfs["beat_rnaseq"].iloc[:, 2].sum()
# Out:
# 4001.9080350160007

# %%
dfs["drug_mut_cor"].head()
# Out:
#                            DNMT3A      IDH1      NPM1      IDH2     RUNX1  \
# Trametinib (GSK1120212)  0.069469  0.063324  0.035875  0.178590 -0.010058
# Vandetanib (ZD6474)     -0.037514 -0.008074 -0.137700 -0.006413 -0.021164
# Foretinib (XL880)       -0.051905  0.080502 -0.298134  0.016696  0.015147
# Selumetinib (AZD6244)    0.057819  0.108843  0.062277  0.212272 -0.013067
# Pazopanib (GW786034)    -0.139401 -0.060474 -0.164032 -0.030986 -0.038516
#
#                              NRAS     CEBPA      FLT3      TP53      TET2  \
# Trametinib (GSK1120212) -0.330423  0.161437 -0.038159  0.075781  0.130018
# Vandetanib (ZD6474)      0.124218  0.129739 -0.334658  0.210837 -0.002717
# Foretinib (XL880)        0.173535  0.149867 -0.478308  0.224181 -0.062703
# Selumetinib (AZD6244)   -0.359204  0.085146  0.016306  0.028781  0.125220
# Pazopanib (GW786034)     0.309101  0.112027 -0.366641  0.215167  0.007740
#
#                               WT1
# Trametinib (GSK1120212) -0.034415
# ...

# %%
dfs["drug_mut_cor_labels"].head()
# Out:
#                0         1         2         3         4         5    \
# 12-00372  13-00098  13-00118  13-00149  13-00160  13-00163  13-00165
#
#                6         7         8         9    ...       163       164  \
# 12-00372  13-00166  13-00186  13-00195  13-00204  ...  16-01049  16-01138
#
#                165       166       167       168       169       170  \
# 12-00372  16-01151  16-01185  16-01216  16-01219  16-01227  16-01237
#
#                171       172
# 12-00372  16-01262  16-01270
#
# [1 rows x 173 columns]

# %%
dfs["tcga_mut"].head()
# Out:
#               DNMT3A   IDH1   NPM1   IDH2  RUNX1   NRAS  CEBPA   FLT3   TP53  \
# TCGA.AB.2803   False  False  False  False  False  False  False  False  False
# TCGA.AB.2805   False  False  False   True   True  False  False  False  False
# TCGA.AB.2806   False  False  False  False  False  False  False  False  False
# TCGA.AB.2807   False  False  False   True   True  False  False  False  False
# TCGA.AB.2808   False  False  False  False  False   True   True  False  False
#
#                TET2    WT1
# TCGA.AB.2803  False  False
# TCGA.AB.2805  False  False
# TCGA.AB.2806  False  False
# TCGA.AB.2807  False  False
# TCGA.AB.2808  False  False

# %%
dfs["tcga_rna"].iloc[:, 2].sum()
# Out:
# 3.6452627472912535

# %% [markdown]
# # Test trranspose_df

# %%
dfs_t = {}
to_be_transposed = dfs.keys() - ['drug_mut_cor', 'drug_mut_cor_labels']
for table_name in to_be_transposed:
    dfs_t[table_name] = data_prep_utils.transpose_df(dfs[table_name])
print(dfs_t.keys())
# Out:
# dict_keys(['tcga_mut', 'tcga_rna', 'beat_rnaseq', 'beat_drug'])

# %%
dfs_t["beat_drug"].head()
# Out:
#            A-674563  Afatinib (BIBW-2992)  Alisertib (MLN8237)  \
# 12-00066   0.302313              0.270839             2.292925
# 12-00150   0.183573              0.095105            10.000000
# 12-00211  10.000000             10.000000            10.000000
# 12-00258   2.250759              1.042656            10.000000
# 12-00294   0.312102              0.412103             1.731348
#
#           Axitinib (AG-013736)    AZD1480  Barasertib (AZD1152-HQPA)  \
# 12-00066              0.137656   2.429158                       10.0
# 12-00150             10.000000        NaN                       10.0
# 12-00211             10.000000  10.000000                       10.0
# 12-00258             10.000000  10.000000                       10.0
# 12-00294              0.124162  10.000000                       10.0
#
#              BEZ235  BMS-345541  Bortezomib (Velcade)  Bosutinib (SKI-606)  \
# 12-00066   0.038276    1.246408              0.180191             0.325536
# ...

# %%
dfs_t["beat_rnaseq"].head()
# Out:
#             TSPAN6       DPM1      SCYL3   C1orf112          FGR        CFH  \
# 12-00066  0.070215  23.311415  10.532266  11.129094   906.792960   4.739520
# 12-00150  1.709459  32.137834  17.778376  11.253940    49.004499   8.262386
# 12-00211  0.000000  25.117470  37.659392  12.541923   111.834945   2.118341
# 12-00258  0.000000  29.351673  15.647852   8.190423  1004.458236  30.403362
# 12-00294  0.000000  31.240770  39.189992  18.875313   267.852800   2.388038
#
#               FUCA2       GCLC       NFYA      STPG1  ...  RP11-218F10.3  \
# 12-00066  43.849332  44.340838  57.435955   4.177799  ...       0.491506
# 12-00150  84.589743  39.346054  32.052361  10.199774  ...       0.142455
# 12-00211  59.078171  67.349788  77.470749   7.767250  ...       1.513101
# 12-00258  30.020930  44.011575  51.692089   5.035358  ...       0.286824
# 12-00294  37.325360  56.429663  60.060789   6.379005  ...       1.962771
#
#           RP11-686O6.2  RP11-313P22.1  RP11-548H3.1  RP11-102N12.3  \
# ...

# %%
dfs_t["tcga_mut"].head()
# Out:
#               DNMT3A   IDH1   NPM1   IDH2  RUNX1   NRAS  CEBPA   FLT3   TP53  \
# TCGA.AB.2803   False  False  False  False  False  False  False  False  False
# TCGA.AB.2805   False  False  False   True   True  False  False  False  False
# TCGA.AB.2806   False  False  False  False  False  False  False  False  False
# TCGA.AB.2807   False  False  False   True   True  False  False  False  False
# TCGA.AB.2808   False  False  False  False  False   True   True  False  False
#
#                TET2    WT1
# TCGA.AB.2803  False  False
# TCGA.AB.2805  False  False
# TCGA.AB.2806  False  False
# TCGA.AB.2807  False  False
# TCGA.AB.2808  False  False

# %%
dfs_t["tcga_rna"].head()
# Out:
#                    A1BG  A1CF  A2BP1     A2LD1        A2M     A2ML1  \
# TCGA.AB.2803  21.786275   0.0    0.0  3.772166  24.673141  0.108692
# TCGA.AB.2805   5.251160   0.0    0.0  3.007237   0.995091  0.207309
# TCGA.AB.2806  10.866631   0.0    0.0  2.951634   0.406560  0.332639
# TCGA.AB.2807  18.869409   0.0    0.0  2.491801  18.714176  0.054085
# TCGA.AB.2808   8.199836   0.0    0.0  2.934105  15.931201  0.342311
#
#                  A4GALT     A4GNT  AAA1       AAAS  ...     ZWILCH      ZWINT  \
# TCGA.AB.2803   0.597809  0.000000   0.0  27.173063  ...  21.150422  13.043071
# TCGA.AB.2805   0.041459  0.165849   0.0  33.003750  ...  34.532453  23.301644
# TCGA.AB.2806   1.034880  0.073922   0.0  29.272380  ...  42.643793  25.650289
# TCGA.AB.2807   6.328205  0.270434   0.0  37.969229  ...  35.305970  39.321409
# TCGA.AB.2808  11.345199  0.048899   0.0  27.629468  ...  55.243286  48.119281
#
#                   ZXDA       ZXDB        ZXDC    ZYG11A      ZYG11B  \
# ...

# %% [markdown]
# # Test get_data_reorgenized

# %%
drugs_reorg = data_prep_utils.get_data_reorgenized(dfs_t["beat_rnaseq"], dfs_t["beat_drug"])

# %%
print(f"drugs transposed shape: {dfs_t['beat_drug'].shape}\ndrugs re shape: {drugs_reorg.shape}")
drugs_reorg.head()
# Out:
# drugs transposed shape: (198, 79)
# drugs re shape: (198, 79)
#            A-674563  Afatinib (BIBW-2992)  Alisertib (MLN8237)  \
# 12-00066   0.302313              0.270839             2.292925
# 12-00150   0.183573              0.095105            10.000000
# 12-00211  10.000000             10.000000            10.000000
# 12-00258   2.250759              1.042656            10.000000
# 12-00294   0.312102              0.412103             1.731348
#
#           Axitinib (AG-013736)    AZD1480  Barasertib (AZD1152-HQPA)  \
# 12-00066              0.137656   2.429158                       10.0
# 12-00150             10.000000        NaN                       10.0
# 12-00211             10.000000  10.000000                       10.0
# 12-00258             10.000000  10.000000                       10.0
# 12-00294              0.124162  10.000000                       10.0
#
#              BEZ235  BMS-345541  Bortezomib (Velcade)  Bosutinib (SKI-606)  \
# ...

# %%
mut_reorg = data_prep_utils.get_data_reorgenized(dfs_t["tcga_rna"], dfs_t["tcga_mut"])

# %%
print(f"muts transposed shape: {dfs_t['tcga_mut'].shape}\nmuts re shape: {mut_reorg.shape}")
mut_reorg.head()
# Out:
# muts transposed shape: (167, 11)
# muts re shape: (167, 11)
#               DNMT3A_y  IDH1_y  NPM1_y  IDH2_y  RUNX1_y  NRAS_y  CEBPA_y  \
# TCGA.AB.2803     False   False   False   False    False   False    False
# TCGA.AB.2805     False   False   False    True     True   False    False
# TCGA.AB.2806     False   False   False   False    False   False    False
# TCGA.AB.2807     False   False   False    True     True   False    False
# TCGA.AB.2808     False   False   False   False    False    True     True
#
#               FLT3_y  TP53_y  TET2_y  WT1_y
# TCGA.AB.2803   False   False   False  False
# TCGA.AB.2805   False   False   False  False
# TCGA.AB.2806   False   False   False  False
# TCGA.AB.2807   False   False   False  False
# TCGA.AB.2808   False   False   False  False

# %% [markdown]
# # Test filter_beat_and_tcga_by_shared_genes

# %%
beat_filt, tcga_filt = data_prep_utils.filter_beat_and_tcga_by_shared_genes(dfs["beat_rnaseq"], dfs["tcga_rna"])

# %%
print(f"{dfs['beat_rnaseq'].shape}\n{beat_filt.shape}\n{dfs['tcga_rna'].shape}\n{tcga_filt.shape}")
# Out:
# (198, 22843)
# (198, 14187)
# (167, 20281)
# (167, 14187)

# %%
beat_filt.head()
# Out:
#             12-00066   12-00150    12-00211     12-00258    12-00294  \
# TSPAN6      0.070215   1.709459    0.000000     0.000000    0.000000
# DPM1       23.311415  32.137834   25.117470    29.351673   31.240770
# SCYL3      10.532266  17.778376   37.659392    15.647852   39.189992
# C1orf112   11.129094  11.253940   12.541923     8.190423   18.875313
# FGR       906.792960  49.004499  111.834945  1004.458236  267.852800
#
#             12-00372   13-00028    13-00034   13-00098    13-00118  ...  \
# TSPAN6      0.921085   0.000000    0.000000   0.000000    0.115955  ...
# DPM1       22.940781  28.176101   34.303196  39.203413   24.089688  ...
# SCYL3      33.734750  23.989937   17.804722  15.450059   25.510139  ...
# C1orf112   11.110592  12.907338    6.758411  23.516117   12.465182  ...
# FGR       170.631056  68.186164  619.473686  11.031520  201.790997  ...
#
#             16-01102    16-01138    16-01151    16-01185    16-01216  \
# ...

# %%
beat_filt_trans = data_prep_utils.transpose_df(beat_filt)

# %%
beat_filt_trans.head()
# Out:
#             TSPAN6       DPM1      SCYL3   C1orf112          FGR        CFH  \
# 12-00066  0.070215  23.311415  10.532266  11.129094   906.792960   4.739520
# 12-00150  1.709459  32.137834  17.778376  11.253940    49.004499   8.262386
# 12-00211  0.000000  25.117470  37.659392  12.541923   111.834945   2.118341
# 12-00258  0.000000  29.351673  15.647852   8.190423  1004.458236  30.403362
# 12-00294  0.000000  31.240770  39.189992  18.875313   267.852800   2.388038
#
#               FUCA2       GCLC       NFYA     NIPAL3  ...      TERC      TSIX  \
# 12-00066  43.849332  44.340838  57.435955  25.207222  ...  0.105323  0.000000
# 12-00150  84.589743  39.346054  32.052361  23.020718  ...  0.256419  0.000000
# 12-00211  59.078171  67.349788  77.470749  71.250225  ...  0.235371  1.513101
# 12-00258  30.020930  44.011575  51.692089  28.299985  ...  0.223085  0.223085
# 12-00294  37.325360  56.429663  60.060789  43.671652  ...  0.163564  0.000000
#
# ...

# %%
drugs_reorg_filt = data_prep_utils.get_data_reorgenized(beat_filt_trans, dfs_t["beat_drug"])

# %%
print(f"{drugs_reorg.shape}\n{drugs_reorg_filt.shape}")
drugs_reorg_filt.head()
# Out:
# (198, 79)
# (198, 79)
#            A-674563  Afatinib (BIBW-2992)  Alisertib (MLN8237)  \
# 12-00066   0.302313              0.270839             2.292925
# 12-00150   0.183573              0.095105            10.000000
# 12-00211  10.000000             10.000000            10.000000
# 12-00258   2.250759              1.042656            10.000000
# 12-00294   0.312102              0.412103             1.731348
#
#           Axitinib (AG-013736)    AZD1480  Barasertib (AZD1152-HQPA)  \
# 12-00066              0.137656   2.429158                       10.0
# 12-00150             10.000000        NaN                       10.0
# 12-00211             10.000000  10.000000                       10.0
# 12-00258             10.000000  10.000000                       10.0
# 12-00294              0.124162  10.000000                       10.0
#
#              BEZ235  BMS-345541  Bortezomib (Velcade)  Bosutinib (SKI-606)  \
# ...
