# %% [markdown]
# # Imports

# %%
import data_prep_utils
import missing_vals_utils

# %% [markdown]
# # Test missing_vals_method

# %%
beat_drug_df = data_prep_utils.get_df("beat_drug")
print(beat_drug_df.isna().sum().sum())
beat_drug_df.head()
# Out:
# 378
#                       12-00066   12-00150  12-00211   12-00258   12-00294  \
# A-674563              0.302313   0.183573      10.0   2.250759   0.312102
# Afatinib (BIBW-2992)  0.270839   0.095105      10.0   1.042656   0.412103
# Alisertib (MLN8237)   2.292925  10.000000      10.0  10.000000   1.731348
# Axitinib (AG-013736)  0.137656  10.000000      10.0  10.000000   0.124162
# AZD1480               2.429158        NaN      10.0  10.000000  10.000000
#
#                        12-00372   13-00028   13-00034   13-00098  13-00118  \
# A-674563               1.112644   3.699257   1.522665   5.132768   1.83987
# Afatinib (BIBW-2992)   0.492191   1.126676   0.313330   4.442185   1.09213
# Alisertib (MLN8237)    6.149094  10.000000  10.000000  10.000000  10.00000
# Axitinib (AG-013736)  10.000000  10.000000  10.000000  10.000000  10.00000
# AZD1480               10.000000  10.000000  10.000000  10.000000  10.00000
#
# ...

# %%
beat_drug_df.transpose().iloc[:, :5].describe()
# Out:
#          A-674563  Afatinib (BIBW-2992)  Alisertib (MLN8237)  \
# count  197.000000            196.000000           197.000000
# mean     1.304903              1.429663             7.684371
# std      2.293337              2.014545             3.407865
# min      0.013717              0.013717             0.013717
# 25%      0.169388              0.456232             4.785701
# 50%      0.341521              0.817595            10.000000
# 75%      1.154416              1.405818            10.000000
# max     10.000000             10.000000            10.000000
#
#        Axitinib (AG-013736)     AZD1480
# count            192.000000  194.000000
# mean               5.268121    7.876070
# std                4.331736    3.430889
# min                0.013717    0.013717
# 25%                0.859099    5.524065
# 50%                3.543976   10.000000
# 75%               10.000000   10.000000
# max               10.000000   10.000000

# %%
beat_drug_df_full = missing_vals_utils.missing_vals_method(beat_drug_df.transpose(), "mean")
beat_drug_df_full.transpose().head()
# Out:
#                       12-00066   12-00150  12-00211   12-00258   12-00294  \
# A-674563              0.302313   0.183573      10.0   2.250759   0.312102
# Afatinib (BIBW-2992)  0.270839   0.095105      10.0   1.042656   0.412103
# Alisertib (MLN8237)   2.292925  10.000000      10.0  10.000000   1.731348
# Axitinib (AG-013736)  0.137656  10.000000      10.0  10.000000   0.124162
# AZD1480               2.429158   7.876070      10.0  10.000000  10.000000
#
#                        12-00372   13-00028   13-00034   13-00098  13-00118  \
# A-674563               1.112644   3.699257   1.522665   5.132768   1.83987
# Afatinib (BIBW-2992)   0.492191   1.126676   0.313330   4.442185   1.09213
# Alisertib (MLN8237)    6.149094  10.000000  10.000000  10.000000  10.00000
# Axitinib (AG-013736)  10.000000  10.000000  10.000000  10.000000  10.00000
# AZD1480               10.000000  10.000000  10.000000  10.000000  10.00000
#
# ...

# %%
beat_drug_df_full.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # Test missing_vals_knn

# %%
beat_drug_df[beat_drug_df.isna().any(axis=1)].head()
# Out:
#                       12-00066   12-00150  12-00211   12-00258   12-00294  \
# A-674563              0.302313   0.183573      10.0   2.250759   0.312102
# Afatinib (BIBW-2992)  0.270839   0.095105      10.0   1.042656   0.412103
# Alisertib (MLN8237)   2.292925  10.000000      10.0  10.000000   1.731348
# Axitinib (AG-013736)  0.137656  10.000000      10.0  10.000000   0.124162
# AZD1480               2.429158        NaN      10.0  10.000000  10.000000
#
#                        12-00372   13-00028   13-00034   13-00098  13-00118  \
# A-674563               1.112644   3.699257   1.522665   5.132768   1.83987
# Afatinib (BIBW-2992)   0.492191   1.126676   0.313330   4.442185   1.09213
# Alisertib (MLN8237)    6.149094  10.000000  10.000000  10.000000  10.00000
# Axitinib (AG-013736)  10.000000  10.000000  10.000000  10.000000  10.00000
# AZD1480               10.000000  10.000000  10.000000  10.000000  10.00000
#
# ...

# %%
beat_drug_k_full = missing_vals_utils.missing_vals_knn(beat_drug_df)
beat_drug_k_full.head()
# Out:
#                       12-00066   12-00150  12-00211   12-00258   12-00294  \
# A-674563              0.302313   0.183573      10.0   2.250759   0.312102
# Afatinib (BIBW-2992)  0.270839   0.095105      10.0   1.042656   0.412103
# Alisertib (MLN8237)   2.292925  10.000000      10.0  10.000000   1.731348
# Axitinib (AG-013736)  0.137656  10.000000      10.0  10.000000   0.124162
# AZD1480               2.429158  10.000000      10.0  10.000000  10.000000
#
#                        12-00372   13-00028   13-00034   13-00098  13-00118  \
# A-674563               1.112644   3.699257   1.522665   5.132768   1.83987
# Afatinib (BIBW-2992)   0.492191   1.126676   0.313330   4.442185   1.09213
# Alisertib (MLN8237)    6.149094  10.000000  10.000000  10.000000  10.00000
# Axitinib (AG-013736)  10.000000  10.000000  10.000000  10.000000  10.00000
# AZD1480               10.000000  10.000000  10.000000  10.000000  10.00000
#
# ...
